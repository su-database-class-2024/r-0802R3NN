# %% [markdown]
# # SQL for accessing spatial data on postgreSQL

# %% [markdown]
# データベースシステム講義資料
# version 0.0.1
# authors: H. Chenan & N. Tsutsumida
#
# Copyright (c) 2023 Narumasa Tsutsumida
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %% [markdown]
# ## Task

# %% [markdown]
# F8. （自由課題１）OpenStreetMapのデータを用いたテーマを自由に設定し、データを抽出し、結果を地図で示せ
#
# テーマ　関東の1都6県の全鉄道駅を抽出し地図化する

# %% [markdown]
# ## prerequisites

# %%
import os
from sqlalchemy import create_engine
import pandas as pd
import geopandas as gpd
import numpy as np
import folium
pd.set_option('display.max_columns', 100)

# %%
def query_geopandas(sql, db):
    """
    Executes a SQL query on a postGIS and returns the result as a GeoPandas GeoDataFrame.

    Args:
        sql (str): The SQL query to execute.
        db (str): The name of the PostgreSQL database to connect to.

    Returns:
        geopandas.GeoDataFrame: The result of the SQL query as a GeoPandas GeoDataFrame.
    """
    DATABASE_URL = 'postgresql://postgres:postgres@postgis_container:5432/{}'.format(db)
    conn = create_engine(DATABASE_URL)
    query_result_gdf = gpd.GeoDataFrame.from_postgis(
        sql, conn, geom_col='way') #geom_col='way' when using osm_kanto, geom_col='geom' when using gisdb
    return query_result_gdf

# %% [markdown]
# ## Define a sql command

# %%
# " "のなかにSQL文を記述
sql = """
    select pt.*
    from planet_osm_point pt, adm2 poly
    where pt.railway='station' and
    poly.name_1 in ('Tokyo', 'Kanagawa', 'Saitama', 'Chiba', 'Ibaraki', 'Tochigi', 'Gunma') and
    st_within(pt.way,st_transform(poly.geom, 3857));
    """

# %% [markdown]
# ## Outputs

# %%
# sample_mapping_X.ipynbから適切なものを選択し使用する
def display_interactive_map(gdf):
    if gdf.crs != 'EPSG:4326':
        gdf = gdf.to_crs(epsg=4326)
    # Create a base map
    m = folium.Map(location=[35.8616, 139.6455], zoom_start=12)  # You can modify the location as per your dataset

    # Add data points to the map
    for _, row in gdf.iterrows():
        coords = (row['way'].y, row['way'].x)
        folium.Marker(location=coords, popup=row['name']).add_to(m)

    return m

# %%
out = query_geopandas(sql,'gisdb')
map_display = display_interactive_map(out)
print(out)
display(map_display)
# Out:
#           osm_id access addr:housename addr:housenumber addr:interpolation  \
# 0      264181231   None           None             None               None
# 1      264180326   None           None             None               None
# 2      263168557   None           None             None               None
# 3      263168723   None           None             None               None
# 4     5660978302   None           None             None               None
# ...          ...    ...            ...              ...                ...
# 2167  3014683053   None           None             None               None
# 2168  3014683087   None           None             None               None
# 2169  3014683078   None           None             None               None
# 2170  3014683058   None           None             None               None
# 2171  3014683072   None           None             None               None
#
#      admin_level aerialway aeroway amenity  area barrier bicycle brand bridge  \
# 0           None      None    None    None  None    None    None  None   None
# 1           None      None    None    None  None    None    None  None   None
# 4     None       None  None         None          station  station  None
# ...    ...        ...   ...          ...              ...      ...   ...
# 2167  None       None  None         None          station  station  None
# 2168  None       None  None         None          station  station  None
# 2169  None       None  None         None          station  station  None
# 2170  None       None  None         None          station  station  None
# 2171  None       None  None         None          station  station  None
#
#      religion route service  shop sport surface  toll tourism tower:type  \
# 0        None  None    None  None  None    None  None    None       None
# 1        None  None    None  None  None    None  None    None       None
# 2        None  None    None  None  None    None  None    None       None
# 3        None  None    None  None  None    None  None    None       None
# 4        None  None    None  None  None    None  None    None       None
# ...       ...   ...     ...   ...   ...     ...   ...     ...        ...
# 2167     None  None    None  None  None    None  None    None       None
# 2168     None  None    None  None  None    None  None    None       None
# 2169     None  None    None  None  None    None  None    None       None
# 2170     None  None    None  None  None    None  None    None       None
# 2171     None  None    None  None  None    None  None    None       None
#
#      tunnel water waterway wetland width  wood z_order  \
# 0      None  None     None    None  None  None    None
# 1      None  None     None    None  None  None    None
# 2      None  None     None    None  None  None    None
# 3      None  None     None    None  None  None    None
# 4      None  None     None    None  None  None    None
# ...     ...   ...      ...     ...   ...   ...     ...
# 2167   None  None     None    None  None  None    None
# 2168   None  None     None    None  None  None    None
# 2169   None  None     None    None  None  None    None
# 2170   None  None     None    None  None  None    None
# 2171   None  None     None    None  None  None    None
#
#                                    way
# 0     POINT (15602052.618 4446844.719)
# 1     POINT (15598044.003 4442284.439)
# 2     POINT (15626500.615 4413461.660)
# 3     POINT (15623765.362 4407216.628)
# 4     POINT (15671343.924 4417773.154)
# ...                                ...
# 2167  POINT (15605914.769 4181383.192)
# 2168  POINT (15615727.560 4183037.792)
# 2169  POINT (15609879.780 4179963.243)
# 2170  POINT (15623856.210 4189420.105)
# 2171  POINT (15626966.844 4194186.778)
#
# [2172 rows x 70 columns]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_279d7e2c8c5eeb41582c49ba4380d925 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_279d7e2c8c5eeb41582c49ba4380d925&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_279d7e2c8c5eeb41582c49ba4380d925 = L.map(
#                 &quot;map_279d7e2c8c5eeb41582c49ba4380d925&quot;,
#                 {
#                     center: [35.8616, 139.6455],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_915aa82613400355f0debd05a1e35f28 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_279d7e2c8c5eeb41582c49ba4380d925);
#
#
#             var marker_232383458f59f6181cb97f06919db558 = L.marker(
#                 [37.05549369985526, 140.15562329999997],
#                 {}
#             ).addTo(map_279d7e2c8c5eeb41582c49ba4380d925);
#
#
#         var popup_2932f0c514d025e7748d20d694112d53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48e81f23217bb95e898125ebef94c5cd = $(`&lt;div id=&quot;html_48e81f23217bb95e898125ebef94c5cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;豊原&lt;/div&gt;`)[0];
#                 popup_2932f0c514d025e7748d20d694112d53.setContent(html_48e81f23217bb95e898125ebef94c5cd);
#
#
#
#         marker_232383458f59f6181cb97f06919db558.bindPopup(popup_2932f0c514d025e7748d20d694112d53)
#         ;
#
#
#
#
#             var marker_23e4f0bf7cf225a9188611e8b32ff605 = L.marker(
#                 [37.022793899851166, 140.1196133],
#                 {}
#             ).addTo(map_279d7e2c8c5eeb41582c49ba4380d925);
#
#
#         var popup_9a0c5aede34d700f6f928ba0793b1d15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5efd99417443008eee83b640ba1c031 = $(`&lt;div id=&quot;html_e5efd99417443008eee83b640ba1c031&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;黒田原&lt;/div&gt;`)[0];
#                 popup_9a0c5aede34d700f6f928ba0793b1d15.setContent(html_e5efd99417443008eee83b640ba1c031);
#
#
#
#         marker_23e4f0bf7cf225a9188611e8b32ff605.bindPopup(popup_9a0c5aede34d700f6f928ba0793b1d15)
#         ;
#
#
#
#
#             var marker_c4e405fad39c8db9c62aade6d3f18406 = L.marker(
#                 [36.81579259982569, 140.3752434],
#                 {}
#             ).addTo(map_279d7e2c8c5eeb41582c49ba4380d925);
#
#
#         var popup_d1ac57110830a0e171b75532cf8d0626 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c015c83756c13f8c6c42161aa88680d3 = $(`&lt;div id=&quot;html_c015c83756c13f8c6c42161aa88680d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;下野宮&lt;/div&gt;`)[0];
#                 popup_d1ac57110830a0e171b75532cf8d0626.setContent(html_c015c83756c13f8c6c42161aa88680d3);
#
#
#
#         marker_c4e405fad39c8db9c62aade6d3f18406.bindPopup(popup_d1ac57110830a0e171b75532cf8d0626)
#         ;
#
#
#
#
#             var marker_ce0a8346bca26d8b1bfc115b0bd4b1b4 = L.marker(
#                 [36.770867599820285, 140.3506722],
#                 {}
#             ).addTo(map_279d7e2c8c5eeb41582c49ba4380d925);
#
#
#         var popup_895d391a7c51219313082f28cbb48a52 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_587186a0e45ff006034bfcfe2a6a08c7 = $(`&lt;div id=&quot;html_587186a0e45ff006034bfcfe2a6a08c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;常陸大子&lt;/div&gt;`)[0];
#                 popup_895d391a7c51219313082f28cbb48a52.setContent(html_587186a0e45ff006034bfcfe2a6a08c7);
#
#
#
#         marker_ce0a8346bca26d8b1bfc115b0bd4b1b4.bindPopup(popup_895d391a7c51219313082f28cbb48a52)
#         ;
#
#
#
#
#             var marker_5b00ef154a400604f7fafad8ae5b90bf = L.marker(
#                 [36.84679289982944, 140.7780777],
#                 {}
#             ).addTo(map_279d7e2c8c5eeb41582c49ba4380d925);
#
#
#         var popup_27a762be383ba547c08386abded83354 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0448cafac4fb838859a25259e0146e3c = $(`&lt;div id=&quot;html_0448cafac4fb838859a25259e0146e3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;大津港&lt;/div&gt;`)[0];
#                 popup_27a762be383ba547c08386abded83354.setContent(html_0448cafac4fb838859a25259e0146e3c);
#
#
#
#         marker_5b00ef154a400604f7fafad8ae5b90bf.bindPopup(popup_27a762be383ba547c08386abded83354)
#         ;
#
#
#
#
#             var marker_64a851453d25e133ecced69ee03123af = L.marker(
#                 [36.75441029981832, 140.3795926999
